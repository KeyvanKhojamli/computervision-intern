# %%
import cv2
import matplotlib.pyplot as plt

# %%
#read image
img = cv2.imread('../level1/example.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#canny detection

cannyimage100_200 = cv2.Canny(img ,100,200)
plt.imshow(cannyimage100_200)

# %%
#canny detection

cannyimage100_250 = cv2.Canny(img ,100,250)
plt.imshow(cannyimage100_250)

# %%
#canny detection

cannyimage0_100 = cv2.Canny(img ,0,100)
plt.imshow(cannyimage0_100)

# %%
#canny detection

cannyimage150_250 = cv2.Canny(img ,150,250)
plt.imshow(cannyimage150_250)
